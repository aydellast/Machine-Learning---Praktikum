# %%
import pandas as pd

# baca file CSV lain, file hour.csv
df = pd.read_csv("../data/hour.csv", sep=",")

# cetak header data (5 baris data) dari file
df.head()

# step 2: buat dataframe baru dengan kolom tertentu
df1 = df[["instant", "dteday", "season", "temp", "hum", "windspeed"]]

# step 3: cetak dataframe baru ke layar
df1.head()

# step 4: simpan dataframe baru ke file CSV
df1.to_csv("../data/latihan01.csv", index=False)

# cek isi file hasil simpan
df_check = pd.read_csv("../data/latihan01.csv")
df_check.head()
# Out:
#    instant      dteday  season  temp   hum  windspeed
# 0        1  2011-01-01       1  0.24  0.81        0.0
# 1        2  2011-01-01       1  0.22  0.80        0.0
# 2        3  2011-01-01       1  0.22  0.80        0.0
# 3        4  2011-01-01       1  0.24  0.75        0.0
# 4        5  2011-01-01       1  0.24  0.75        0.0
